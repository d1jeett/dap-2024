# %% [markdown]
# <a href="https://colab.research.google.com/github/d1jeett/dap-2024/blob/main/les01/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
git add dap-2024/tree/main/les01
git commit -m "Добавлен отчет по работе"
git push origin main
# Out:
#   File "/tmp/ipython-input-33795501.py", line 1
#     git add dap-2024/tree/main/les01
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1. Типы ячеек в Jupyter Notebook.
#   Raw — «сырой» текст без обработки. Notebook не пытается интерпретировать Markdown или выполнять код. Обычно используется при экспорте в другие форматы.
# - Code (кодовая ячейка) — в неё пишут и запускают код (чаще всего Python). Результат выполнения отображается прямо под ячейкой: вывод, графики, таблицы и т.п.
# -  Markdown — ячейка для текста, оформленного с помощью Markdown: заголовки, списки, формулы, изображения, форматированный текст. Используется для пояснений, описаний и оформления отчётов.
# -  Raw — «сырой» текст без обработки. Notebook не пытается интерпретировать Markdown или выполнять код. Обычно используется при экспорте в другие форматы.
#
#
# ---
#
#
# 2. Как с помощью Markdown сформировать иерархический список?
# Иерархический список в Markdown создаётся с помощью обычных маркеров списка, а вложенность формируется за счёт отступов. Делаешь пункт, а чтобы создать подпункт, ставишь перед ним несколько пробелов — обычно два или четыре. Чем больше отступ, тем глубже уровень списка.
#
#
# ---
#
#
# 3. Как с помощью Markdown оформить цитату?
# Ставится символ > перед строкой, и она становится оформленной как цитата. Если хочешь многострочную цитату, ставишь > перед каждой строкой. Также можно делать вложенные цитаты, если поставить >>, но это используют редко.
#
#
# ---
#
#
# 4. Как в текстовую ячейку вставить отформатированный блок кода?
# Нужно написать три обратные кавычки ``` перед кодом и три такие же после него. Это создаст отдельный красиво оформленный блок. Ну или просто выбрать кнопку на экране быстрого доступа вверху.
#
#
#
# ---
#
# 5. Сколько уровней заголовка существует в Markdown?
# В Markdown существует шесть уровней заголовков. Самый большой заголовок создаётся одним символом #, дальше идут ##, ###, ####, ##### и самый маленький ######. Каждый уровень делает текст меньше и показывает иерархию.
#
# ---
#
# 6. Шаги процесса анализа данных, рассказать подробно про один из шагов (на выбор преподавателя).
# Процесс анализа данных обычно включает несколько шагов: постановка задачи, сбор данных, очистка данных, разведочный анализ (EDA), построение модели, оценка результатов и интерпретация.Например, шаг очистка данных очень важен. На этом этапе проверяют данные на ошибки, пропуски и дубликаты. Пропуски могут заполнять средним, медианой или специальными значениями. Дубликаты удаляют, чтобы данные не исказили результаты. Также проверяют типы данных, исправляют неправильные форматы (например даты), обрабатывают выбросы и приводят данные к единообразному виду. Если этот шаг сделать плохо, последующий анализ или модели будут работать неверно, поэтому очистка данных часто занимает больше всего времени.
#
# ---
#
# 7. Типы данных, рассказать подробно про один из типов данных (на выбор преподавателя).
# Основные типы данных в анализе: числовые, категориальные, текстовые, временные и булевы. Например, категориальные данные — это данные, которые представляют разные категории, например цвет, страна, тип объекта или статус. У них нет числового смысла, то есть нельзя просто взять среднее. Для работы с моделями их обычно кодируют: используют one-hot encoding (каждая категория становится отдельным бинарным признаком), label encoding (каждой категории присваивается число) или frequency encoding (замена категории на частоту её встречаемости). Также важно следить за редкими или новыми категориями, чтобы модели правильно с ними работали. Категориальные данные часто визуализируют столбчатыми диаграммами или сводными таблицами.
#
# ---
#
# 8. Что такое Jupyter Notebook, для чего используется?
# Jupyter Notebook — это интерактивная среда, где код и текст можно писать вместе в одном документе. В ячейках можно запускать код (обычно Python), вставлять текст с форматированием через Markdown, изображения, формулы и графики. Он используется для анализа данных, визуализации, экспериментов, обучения, создания отчётов и прототипирования моделей, потому что позволяет сразу видеть результат и делать пояснения прямо рядом с кодом.
#
# ---
#
# 9. Почему python популярен для анализа данных?
# Python популярен для анализа данных из-за простого и понятного синтаксиса, который легко читать и писать. У него огромная экосистема библиотек для работы с данными: pandas для обработки таблиц, numpy для числовых вычислений, matplotlib и seaborn для визуализации, scikit-learn для машинного обучения и многие другие. Python хорошо интегрируется с другими инструментами, поддерживает работу с большими данными и машинным обучением, а также имеет большое сообщество и множество примеров и обучающих материалов. Все это делает его удобным для анализа, экспериментов и быстрого прототипирования.
#
# ---
#
# 10. Обязательно ли использовать Jupyter Notebook для анализа данных?
# Использование Jupyter Notebook для анализа данных не обязательно. Это просто удобный инструмент для интерактивной работы, визуализации и заметок прямо рядом с кодом. Анализ данных можно делать и через обычные Python-скрипты (.py), в IDE вроде VSCode или PyCharm, в других ноутбуках типа Google Colab, RStudio или в профессиональных средах вроде Databricks. Jupyter удобен для экспериментов и отчётов, но для больших проектов, автоматизации или продакшена часто используют обычные скрипты и модули.
