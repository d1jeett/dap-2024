# %% [markdown]
# <a href="https://colab.research.google.com/github/d1jeett/dap-2024/blob/main/les04/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа №4.
# # Анализ данных пассажиров "Титаника"
#
# Гибель Титаника – одно из самых печально известных кораблекрушений в истории.
#
# 15 апреля 1912 года во время своего первого плавания считавшийся «непотопляемым» «Титаник» затонул после столкновения с айсбергом.
# К сожалению, спасательных шлюпок для всех находившихся на борту не хватило, в результате чего погибли 1502 из 2224 пассажиров и членов экипажа.
#
# Используя набор данных titanic.csv выполните следующие 10 заданий.

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()  # выберите файл titanic.csv

df = pd.read_csv('titanic.csv')
df.head()
# Out:
#      <input type="file" id="files-2a73db24-fa83-4c5e-8262-0082f566aa9e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a73db24-fa83-4c5e-8262-0082f566aa9e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 1. Создайте DataFarame из файла titanic.csv, в качестве индекса используйте столбец "PassengerId"

# %%
import pandas as pd

df = pd.read_csv('titanic.csv', index_col='PassengerId')
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# 2. Просмотрите первые 6 строк

# %%
df.head(6)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# ...

# %% [markdown]
# 3. Выведите описание данных

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# 4. Сколько мужчин / женщин находилось на борту?

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# 4. Выведите распределение переменной Pclass (социально-экономический статус) и это же распределение, только для мужчин / женщин по отдельности. Сколько было мужчин 2-го класса

# %%
df.groupby(['Pclass', 'Sex']).size()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# dtype: int64

# %% [markdown]
# 5. Каковы медиана и среднеквадрати́чное отклонение платежей (Fare)? Округлите до 2 десятичных знаков.

# %%
median_fare = round(df['Fare'].median(), 2)
std_fare = round(df['Fare'].std(), 2)

median_fare, std_fare
# Out:
# (14.45, 49.69)

# %% [markdown]
# 6. Правда ли, что люди моложе 30 лет выживали чаще, чем люди старше 60 лет? Каковы доли выживших в обеих группах?

# %%
young = df[df['Age'] < 30]
old = df[df['Age'] > 60]

young_rate = young['Survived'].mean()
old_rate = old['Survived'].mean()

print(f"Моложе 30 лет: {young_rate:.1%}")
print(f"Старше 60 лет: {old_rate:.1%}")
print(f"Выживаемость выше у {'молодых' if young_rate > old_rate else 'пожилых'}")
# Out:
# Моложе 30 лет: 40.6%
# Старше 60 лет: 22.7%
# Выживаемость выше у молодых

# %% [markdown]
# 7. Правда ли, что женщины выживали чаще мужчин? Каковы доли выживших в обеих группах?

# %%
female_rate = df[df['Sex'] == 'female']['Survived'].mean()
male_rate = df[df['Sex'] == 'male']['Survived'].mean()

print(f"Женщины: {female_rate:.1%}")
print(f"Мужчины: {male_rate:.1%}")
print(f"Выживаемость выше у {'женщин' if female_rate > male_rate else 'мужчин'}")
# Out:
# Женщины: 74.2%
# Мужчины: 18.9%
# Выживаемость выше у женщин

# %% [markdown]
# 8.  Найдите самое популярное имя среди пассажиров Титаника мужского пола?

# %%
male_names = df[df['Sex'] == 'male']['Name'].str.extract(r'\. (\w+)')[0]

top_name = male_names.value_counts().index[0]
count = male_names.value_counts().iloc[0]

print(f"Самое популярное имя: {top_name}")
print(f"Встречается {count} раз")
# Out:
# Самое популярное имя: William
# Встречается 35 раз

# %% [markdown]
# 9. Как отличается средний возраст мужчин / женщин в зависимости от класса обслуживания? Выберите верные утверждения:
#
#     В среднем мужчины 1-го класса старше 40 лет
#     В среднем женщины 1-го класса старше 40 лет
#     Мужчины всех классов в среднем старше женщин того же класса
#     В среднем люди в 1 классе старше, чем во 2-ом, а те старше представителей 3-го класса

# %%
# Средний возраст по полу и классу
avg_age = df.groupby(['Pclass', 'Sex'])['Age'].mean()

print("Средний возраст:")
for (pclass, sex), age in avg_age.items():
    print(f"Класс {pclass}, {sex}: {age:.1f} лет")

# Проверка утверждений
print("\nПроверка утверждений:")

# 1. Мужчины 1-го класса старше 40 лет?
male_1st = avg_age.loc[(1, 'male')]
print(f"1. Мужчины 1 класса {male_1st:.1f} лет - {'ДА' if male_1st > 40 else 'НЕТ'}")

# 2. Женщины 1-го класса старше 40 лет?
female_1st = avg_age.loc[(1, 'female')]
print(f"2. Женщины 1 класса {female_1st:.1f} лет - {'ДА' if female_1st > 40 else 'НЕТ'}")

# 3. Мужчины старше женщин того же класса?
for pclass in [1, 2, 3]:
    male_age = avg_age.loc[(pclass, 'male')]
    female_age = avg_age.loc[(pclass, 'female')]
    print(f"3.{pclass} Муж {male_age:.1f} vs Жен {female_age:.1f} - {'ДА' if male_age > female_age else 'НЕТ'}")

# 4. 1 класс старше 2-го, 2 старше 3-го?
for sex in ['male', 'female']:
    age_1 = avg_age.loc[(1, sex)]
    age_2 = avg_age.loc[(2, sex)]
    age_3 = avg_age.loc[(3, sex)]
    print(f"4.{sex} 1кл {age_1:.1f} > 2кл {age_2:.1f} > 3кл {age_3:.1f} - {'ДА' if age_1 > age_2 > age_3 else 'НЕТ'}")
# Out:
# Средний возраст:
# Класс 1, female: 34.6 лет
# Класс 1, male: 41.3 лет
# Класс 2, female: 28.7 лет
# Класс 2, male: 30.7 лет
# Класс 3, female: 21.8 лет
# Класс 3, male: 26.5 лет
#
# Проверка утверждений:
# 1. Мужчины 1 класса 41.3 лет - ДА
# 2. Женщины 1 класса 34.6 лет - НЕТ
# 3.1 Муж 41.3 vs Жен 34.6 - ДА
# 3.2 Муж 30.7 vs Жен 28.7 - ДА
# 3.3 Муж 26.5 vs Жен 21.8 - ДА
# 4.male 1кл 41.3 > 2кл 30.7 > 3кл 26.5 - ДА
# 4.female 1кл 34.6 > 2кл 28.7 > 3кл 21.8 - ДА

# %% [markdown]
# 10. Сравните возраст у спасенных и у погибших пасажиров. Средний возраст погибших выше, верно?

# %%
survived_age = df[df['Survived'] == 1]['Age'].mean()
died_age = df[df['Survived'] == 0]['Age'].mean()

print(f"Средний возраст спасенных: {survived_age:.1f} лет")
print(f"Средний возраст погибших: {died_age:.1f} лет")
print(f"Погибшие старше? {'ДА' if died_age > survived_age else 'НЕТ'} ({died_age-survived_age:+.1f} лет)")
# Out:
# Средний возраст спасенных: 28.3 лет
# Средний возраст погибших: 30.6 лет
# Погибшие старше? ДА (+2.3 лет)

# %% [markdown]
# ### Дополнительные вопросы для защиты
#
# Что такое медиана? — Значение, которое делит упорядоченный ряд пополам. Для расчета: sorted(numbers)[len(numbers)//2]
#
# Что такое дисперсия? — Среднее квадратов отклонений от среднего. Формула: sum((x - mean)**2) / (n-1)
#
# Что такое СКО? — Корень из дисперсии: sqrt(variance)
#
# Series vs DataFrame — Series — одномерный массив с индексами, DataFrame — двумерная таблица из Series.
#
# Изменить индекс в Series? — Да: s.index = new_index или s.rename(index=mapping)
#
# Сложение Series:
#
# (Да)Одинаковые тип, размер, индексы
#
# (Да)Одинаковые тип, размер, разные индексы → NaN для несовпадений
#
# (Нет)Одинаковые тип, разный размер, одинаковые индексы → ошибка
#
# (Нет)Разные типы, одинаковые размер, индексы → приведение если возможно
#
# (Нет)Разные типы, одинаковые размер, разные индексы → приведение + NaN
#
# (Нет)Разные типы, размеры, индексы → ошибка
#
# DataFrame — Таблица (много Series), Series — один столбец/ряд.
#
# Показать 8 строк в DataFrame — pd.set_option('display.max_rows', 8)
#
# iloc vs loc — iloc — по номеру позиции (0,1,2...), loc — по значению индекса.
#
# Добавить Series в DataFrame — Да: df['new_col'] = series
#
# Библиотеки для загрузки:
#
# CSV: нет (встроено)
#
# Excel: да (нужен openpyxl или xlrd)
#
# JSON: нет (встроено)
